# %%
import numpy as np

# 1–2: Đọc file
heights = np.loadtxt('heights_1.txt')
weights = np.loadtxt('weights_1.txt')

# 3: inch → meter
arr_height_m = heights * 0.0254

# 4: pound → kg
arr_weight_kg = weights * 0.453592

# 5: Tính BMI
arr_bmi = arr_weight_kg / (arr_height_m ** 2)

# 6: In phần tử thứ 50 của arr_weight_kg
print("Weight index 50 (kg):", arr_weight_kg[50])

# 7: 100 phần tử bắt đầu từ chỉ số 100
arr_height_m_100 = arr_height_m[100:200]
print("100 elements starting at index 100:", arr_height_m_100)

# 8: Vị trí BMI < 21
print("Indices BMI < 21:", np.where(arr_bmi < 21)[0])

# 9: Mean height, mean weight
print("Mean height:", heights.mean())
print("Mean weight:", weights.mean())

# 10–11: Min/Max
print("Max height:", heights.max(), " Min height:", heights.min())
print("Max weight:", weights.max(), " Min weight:", weights.min())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import numpy as np
#       3 # 1–2: Đọc file
# ----> 4 heights = np.loadtxt('heights_1.txt')
#       5 weights = np.loadtxt('weights_1.txt')
#       7 # 3: inch → meter
#
# File c:\Users\Windows 10\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
#    1395     delimiter = delimiter.decode('latin1')
# -> 1397 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1398             converters=converters, skiplines=skiprows, usecols=usecols,
#    1399             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1400             max_rows=max_rows, quote=quotechar)
# ...
