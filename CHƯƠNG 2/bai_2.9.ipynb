# %%
import json
data = [
    {"name": "Minh", "age": 21},
    {"name": "Huy", "age": 19},
    {"name": "Lan", "age": 22}
]
sorted_data = sorted(data, key=lambda x: x["age"])
print(json.dumps(sorted_data, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "name": "Huy",
#         "age": 19
#     },
#     {
#         "name": "Minh",
#         "age": 21
#     },
#     {
#         "name": "Lan",
#         "age": 22
#     }
# ]
