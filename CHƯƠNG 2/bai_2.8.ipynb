# %%
import json
person = {"name": "Huy", "age": 22, "city": "Đà Nẵng"}
json_str = json.dumps(person, indent=4, ensure_ascii=False)
print(json_str)
# Out:
# {
#     "name": "Huy",
#     "age": 22,
#     "city": "Đà Nẵng"
# }
