# %%
import xml.etree.ElementTree as ET
root = ET.Element("congty")
ET.SubElement(root, "tengiamdoc").text = "Nguyễn Văn A"
ET.SubElement(root, "diachi").text = "123 Giải Phóng, Hà Nội"
ET.SubElement(root, "dienthoai").text = "0987654321"
ET.SubElement(root, "masothue").text = "0101234567"
tree = ET.ElementTree(root)
tree.write("congty.xml", encoding="utf-8", xml_declaration=True)
print("✅ Đã tạo file congty.xml thành công!")
# Out:
# ✅ Đã tạo file congty.xml thành công!
