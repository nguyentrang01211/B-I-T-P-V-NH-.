# %%
import json
json_data = '{"name":"Lan","age":20,"city":"Hà Nội"}'
python_obj = json.loads(json_data)
print(type(python_obj))
print(python_obj)
# Out:
# <class 'dict'>
# {'name': 'Lan', 'age': 20, 'city': 'Hà Nội'}
